# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /Users/timoklein/Library/CloudStorage/OneDrive-Personal/Universiteit/Studie/M_Data_Science_and_Society/year_2/Thesis/Code/DSS-Thesis-Timo-Klein

# %%
## Read the CSV file into a DataFrame
df_mm = pd.read_csv('../../Data/used_data/SharedResponsesSurvey.csv')
# Out:
# /var/folders/1r/syrrrqbj2cgc7y5d1z2fgb3r0000gn/T/ipykernel_2246/195239936.py:2: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mm = pd.read_csv('../../Data/used_data/SharedResponsesSurvey.csv')

# %%
df_mm.head(5)
# Out:
#           ResponseID               ExtendedSessionID        UserID  \
# 0  3ubu5Minm7ygqK3oa  -2147481563_6968366610050747.0  6.968367e+15
# 1  FKd9Fje2tWt2sHi6v  -2147481563_6968366610050747.0  6.968367e+15
# 2  J6WRHLj8exr4bNwTm  -2147481563_6968366610050747.0  6.968367e+15
# 3  KcYXwqS3rTrbqdTY2  -2147481563_6968366610050747.0  6.968367e+15
# 4  ZQsAWst58jK9HcKvx  -2147481563_6968366610050747.0  6.968367e+15
#
#    ScenarioOrder  Intervention  PedPed  Barrier  CrossingSignal  \
# 0             13             0       0        0               0
# 1              8             0       1        0               0
# 2              2             0       0        0               2
# 3              1             0       1        0               2
# 4              5             0       1        0               0
#
#   AttributeLevel ScenarioTypeStrict  ... Template DescriptionShown LeftHand  \
# 0         Female             Gender  ...  Desktop              0.0      0.0
# ...

# %%
df_mm.columns
# Out:
# Index(['ResponseID', 'ExtendedSessionID', 'UserID', 'ScenarioOrder',
#        'Intervention', 'PedPed', 'Barrier', 'CrossingSignal', 'AttributeLevel',
#        'ScenarioTypeStrict', 'ScenarioType', 'DefaultChoice',
#        'NonDefaultChoice', 'DefaultChoiceIsOmission', 'NumberOfCharacters',
#        'DiffNumberOFCharacters', 'Saved', 'Template', 'DescriptionShown',
#        'LeftHand', 'UserCountry3', 'Review_age', 'Review_education',
#        'Review_gender', 'Review_income', 'Review_political',
#        'Review_religious'],
#       dtype='object')

# %%
df_tri = pd.read_csv('../../Data/used_data/Technology_Readiness_Index.csv')

# %%
df_tri.head(5)
# Out:
#   Economy_Label            Category_Label  2008_Index_Value  \
# 0   Afghanistan             Overall index               0.1
# 1   Afghanistan                       ICT               0.1
# 2   Afghanistan                    Skills               0.2
# 3   Afghanistan  Research and Development               0.0
# 4   Afghanistan         Industry activity               0.5
#
#    2008_Index_Footnote 2008_Index_MissingValue  2009_Index_Value  \
# 0                  NaN                     NaN               0.1
# 1                  NaN                     NaN               0.1
# 2                  NaN                     NaN               0.2
# 3                  NaN                     NaN               0.0
# 4                  NaN                     NaN               0.4
#
#    2009_Index_Footnote 2009_Index_MissingValue  2010_Index_Value  \
# 0                  NaN                     NaN               0.1
# 1                  NaN                     NaN               0.1
# ...

# %%
# Number of unique values in the 'Economy_Label' column
df_tri['Economy_Label'].nunique()
# Out:
# 167

# %%
df_rtds = pd.read_csv('../../Data/used_data/Road_Traffic_Deaths_Sex.csv')

# %%
df_rtds.head(5)
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0  Countries, territories and areas       Year
# 1                       Afghanistan       2019
# 2                       Afghanistan       2018
# 3                       Afghanistan       2017
# 4                       Afghanistan       2016
#
#   Estimated number of road traffic deaths  \
# 0                              Both sexes
# 1                        6033 [5227-6846]
# 2                        5295 [4578-6017]
# 3                        5490 [4737-6246]
# 4                        5240 [4512-5970]
#
#   Estimated number of road traffic deaths.1  \
# 0                                      Male
# 1                          4853 [4204-5507]
# 2                          4339 [3751-4930]
# 3                          4433 [3825-5043]
# 4                          4239 [3650-4829]
#
#   Estimated number of road traffic deaths.2  \
# 0                                    Female
# 1                          1180 [1023-1339]
# ...

# %%
# Number of unique values in the 'Unnamed: 0' column
df_rtds['Unnamed: 0'].nunique()
# Out:
# 184

# %%
df_rtdu = pd.read_csv('../../Data/used_data/Road_Traffic_Deaths_User.csv')

# %%
df_rtdu.head(5)
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0  Countries, territories and areas       Year
# 1                           Albania       2016
# 2                           Andorra       2013
# 3                            Angola       2016
# 4               Antigua and Barbuda       2016
#
#   Distribution of road traffic deaths by type of road user (%)  \
# 0           Drivers/passengers of 4-wheeled vehicles
# 1                                               39.4
# 2                                                NaN
# 3                                               59.5
# 4                                               62.5
#
#   Distribution of road traffic deaths by type of road user (%).1  \
# 0   Drivers/passengers of motorized 2- or 3-wheelers
# 1                                               11.9
# 2                                               50.0
# 3                                                NaN
# 4                                                0.0
#
# ...

# %%
# Number of unique values in the 'Unnamed: 0' column
df_rtdu['Unnamed: 0'].nunique()
# Out:
# 148

# %%
# Check how many of the values
# Out:
# {'Iraq', 'China', 'Uzbekistan', 'Saudi Arabia', 'Venezuela (Bolivarian Republic of)', 'Yemen', 'Vanuatu', 'Solomon Islands', 'Sao Tome and Principe', 'Malaysia', 'Niger', 'Liberia', "Lao People's Democratic Republic", 'Brunei Darussalam', 'Chad', 'Burkina Faso', 'Cabo Verde', 'Bhutan', 'Bangladesh', 'Cameroon', 'Equatorial Guinea', 'Burundi', "Democratic People's Republic of Korea", 'Mauritania', 'Central African Republic', 'Sierra Leone', 'Guinea', 'Grenada', 'Mozambique', 'Kuwait', 'Algeria', 'Haiti', 'Djibouti', 'Nepal', 'Bosnia and Herzegovina', 'Afghanistan', 'Guinea-Bissau', 'Lesotho', 'Gabon', 'Namibia', 'Gambia', 'Congo'}

# %%
# Scenario, session and user structure
row_count = df.shape[0]
print("Number of rows: ", row_count)
unique_responseid = df['ResponseID'].nunique()
unique_extendedsessionid = df['ExtendedSessionID'].nunique()
unique_userid = df['UserID'].nunique()
counts = df['ExtendedSessionID'].value_counts()
less_than_26 = counts[counts < 26]
num_unique_less_than_26 = len(less_than_26)
print(f"The number of unique values in 'ResponseID' (number of scenarios) is: {unique_responseid}, {unique_responseid - (row_count/2)} only have one outcome")
print(f"The number of unique values in 'ExtendedSessionID' (number of sessions) is: {unique_extendedsessionid}, {num_unique_less_than_26} have less than 26 outcomes")
print(f"The number of unique values in 'UserID' (number of users) is: {unique_userid}")

# Number of different values in the 'Template' column and their (relative) counts
print(df['Template'].value_counts(normalize=True) * 100)

# Number of different values in the 'ScenarioType' column and their (absolute) counts
print(df['ScenarioType'].value_counts(normalize=True) * 100)
# Out:
# Number of rows:  11286141
# The number of unique values in 'ResponseID' (number of scenarios) is: 5836521, 193450.5 only have one outcome
# The number of unique values in 'ExtendedSessionID' (number of sessions) is: 492845, 482834 have less than 26 outcomes
# The number of unique values in 'UserID' (number of users) is: 463675
# Template
# Desktop    73.873266
# Mobile     26.126734
# Name: proportion, dtype: float64
# ScenarioType
# Utilitarian      18.020119
# Species          17.072479
# Gender           17.001542
# Age              16.433784
# Fitness          15.335871
# Random           10.648582
# Social Status     5.487624
# Name: proportion, dtype: float64
# The number of scenario's about Utilitarianism is 1977056
# The number of scenario's where AttributeLevel is More or Less is 2033776
# The number of scenario's where people save the bigger group is 802451
# The number of scenario's where people kill the smaller group is 802451
# ...

# %%
grouped = df.groupby(['ExtendedSessionID', 'ScenarioType']).size().reset_index(name='scenario type occurs ... times per session')
grouped.head(10)

grouped_grouped = grouped.groupby(['ScenarioType', 'scenario type occurs ... times per session']).size().reset_index(name='times scenario type occurs ... times per session')

grouped_age = grouped_grouped[grouped_grouped['ScenarioType'] == 'Age']
grouped_age
# Out:
#    ScenarioType  scenario type occurs ... times per session  \
# 0           Age                                           2
# 1           Age                                           4
# 2           Age                                           6
# 3           Age                                           8
# 4           Age                                          10
# 5           Age                                          12
# 6           Age                                          16
# 7           Age                                          18
# 8           Age                                          20
# 9           Age                                          22
# 10          Age                                          24
# 11          Age                                          26
# 12          Age                                          28
# 13          Age                                          34
# 14          Age                                          36
# ...
