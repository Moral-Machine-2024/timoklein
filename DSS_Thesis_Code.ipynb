# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /Users/timoklein/Library/CloudStorage/OneDrive-Personal/Universiteit/Studie/M_Data_Science_and_Society/year_2/Thesis/Code/timoklein

# %%
## Read the Moral Machine dataset into a DataFrame
df_mm = pd.read_csv('Data/SharedResponsesSurvey.csv')
# Out:
# /var/folders/1r/syrrrqbj2cgc7y5d1z2fgb3r0000gn/T/ipykernel_9688/1654876110.py:2: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mm = pd.read_csv('Data/SharedResponsesSurvey.csv')

# %%
df_mm.head(5)
# Out:
#           ResponseID               ExtendedSessionID        UserID  \
# 0  3ubu5Minm7ygqK3oa  -2147481563_6968366610050747.0  6.968367e+15
# 1  FKd9Fje2tWt2sHi6v  -2147481563_6968366610050747.0  6.968367e+15
# 2  J6WRHLj8exr4bNwTm  -2147481563_6968366610050747.0  6.968367e+15
# 3  KcYXwqS3rTrbqdTY2  -2147481563_6968366610050747.0  6.968367e+15
# 4  ZQsAWst58jK9HcKvx  -2147481563_6968366610050747.0  6.968367e+15
#
#    ScenarioOrder  Intervention  PedPed  Barrier  CrossingSignal  \
# 0             13             0       0        0               0
# 1              8             0       1        0               0
# 2              2             0       0        0               2
# 3              1             0       1        0               2
# 4              5             0       1        0               0
#
#   AttributeLevel ScenarioTypeStrict  ... Template DescriptionShown LeftHand  \
# 0         Female             Gender  ...  Desktop              0.0      0.0
# ...

# %%
## Read the Technology Readiness Index dataset into a DataFrame
df_tri = pd.read_csv('Data/Technology_Readiness_Index.csv')

# %%
df_tri.head(5)
# Out:
#   Economy_Label            Category_Label  2008_Index_Value  \
# 0   Afghanistan             Overall index               0.1
# 1   Afghanistan                       ICT               0.1
# 2   Afghanistan                    Skills               0.2
# 3   Afghanistan  Research and Development               0.0
# 4   Afghanistan         Industry activity               0.5
#
#    2008_Index_Footnote 2008_Index_MissingValue  2009_Index_Value  \
# 0                  NaN                     NaN               0.1
# 1                  NaN                     NaN               0.1
# 2                  NaN                     NaN               0.2
# 3                  NaN                     NaN               0.0
# 4                  NaN                     NaN               0.4
#
#    2009_Index_Footnote 2009_Index_MissingValue  2010_Index_Value  \
# 0                  NaN                     NaN               0.1
# 1                  NaN                     NaN               0.1
# ...

# %%
## Read the Road Traffic Deaths Sex dataset into a DataFrame
df_rtds = pd.read_csv('Data/Road_Traffic_Deaths_Sex.csv')

# %%
df_rtds.head(5)
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0  Countries, territories and areas       Year
# 1                       Afghanistan       2019
# 2                       Afghanistan       2018
# 3                       Afghanistan       2017
# 4                       Afghanistan       2016
#
#   Estimated number of road traffic deaths  \
# 0                              Both sexes
# 1                        6033 [5227-6846]
# 2                        5295 [4578-6017]
# 3                        5490 [4737-6246]
# 4                        5240 [4512-5970]
#
#   Estimated number of road traffic deaths.1  \
# 0                                      Male
# 1                          4853 [4204-5507]
# 2                          4339 [3751-4930]
# 3                          4433 [3825-5043]
# 4                          4239 [3650-4829]
#
#   Estimated number of road traffic deaths.2  \
# 0                                    Female
# 1                          1180 [1023-1339]
# ...

# %%
## Read the Road Traffic Deaths User dataset into a DataFrame
df_rtdu = pd.read_csv('Data/Road_Traffic_Deaths_User.csv')

# %%
df_rtdu.head(5)
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0  Countries, territories and areas       Year
# 1                           Albania       2016
# 2                           Andorra       2013
# 3                            Angola       2016
# 4               Antigua and Barbuda       2016
#
#   Distribution of road traffic deaths by type of road user (%)  \
# 0           Drivers/passengers of 4-wheeled vehicles
# 1                                               39.4
# 2                                                NaN
# 3                                               59.5
# 4                                               62.5
#
#   Distribution of road traffic deaths by type of road user (%).1  \
# 0   Drivers/passengers of motorized 2- or 3-wheelers
# 1                                               11.9
# 2                                               50.0
# 3                                                NaN
# 4                                                0.0
#
# ...
