# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Example: Generating random data (replace with your actual data)
np.random.seed(42)
X = np.random.rand(100, 2)  # 100 samples with 2 features
X[:10]

# If you have a dataset in a CSV file
# df = pd.read_csv('your_dataset.csv')
# X = df[['feature1', 'feature2']].values  # select your relevant features
# Out:
# array([[0.37454012, 0.95071431],
#        [0.73199394, 0.59865848],
#        [0.15601864, 0.15599452],
#        [0.05808361, 0.86617615],
#        [0.60111501, 0.70807258],
#        [0.02058449, 0.96990985],
#        [0.83244264, 0.21233911],
#        [0.18182497, 0.18340451],
#        [0.30424224, 0.52475643],
#        [0.43194502, 0.29122914]])

# %%
# Initialize KMeans with a specified number of clusters (K)
kmeans = KMeans(n_clusters=3, random_state=42)  # K=3 here, adjust as needed

# Fit the model to the data
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Get the cluster labels (which cluster each point belongs to)
labels = kmeans.labels_

# Get the coordinates of the centroids
centroids = kmeans.cluster_centers_

# %%
# Show the unique cluster labels
print('Unique cluster labels:', np.unique(labels))
print('Centroids:', centroids)
# Out:
# Unique cluster labels: [0 1 2]
# Centroids: [[0.8039633  0.57026999]
#  [0.36376248 0.20008043]
#  [0.18520943 0.72228065]]

# %%
# Scatter plot of data points
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', label='Data Points')

# Plot the centroids
plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red', marker='X', label='Centroids')

plt.title('K-means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
inertia = []
K = range(1, 10)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)  # Sum of squared distances

# Plot the Elbow Curve
plt.plot(K, inertia, 'bx-')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia (Sum of squared distances)')
plt.title('Elbow Method For Optimal K')
plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np

# Example dataset with 5 features
X = np.array([
    [25, 50000, 16, 1, 3],   # [age, income, education, political view, traffic deaths]
    [40, 60000, 18, 2, 4],
    [35, 70000, 20, 1, 5],
    # More data points...
])

# Create KMeans model
kmeans = KMeans(n_clusters=3, random_state=42)

# Fit the model to the data
kmeans.fit(X)

# Get the cluster labels
labels = kmeans.labels_

# Get the cluster centroids
centroids = kmeans.cluster_centers_

# Output the results
print("Cluster labels:", labels)
print("Cluster centroids:", centroids)
# Out:
# Cluster labels: [2 0 1]
# Cluster centroids: [[4.0e+01 6.0e+04 1.8e+01 2.0e+00 4.0e+00]
#  [3.5e+01 7.0e+04 2.0e+01 1.0e+00 5.0e+00]
#  [2.5e+01 5.0e+04 1.6e+01 1.0e+00 3.0e+00]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# Example dataset with 5 features
X = np.array([
    [25, 50000, 16, 1, 3],   # [age, income, education, political view, traffic deaths]
    [40, 60000, 18, 2, 4],
    [35, 70000, 20, 1, 5],
    [45, 80000, 15, 3, 2],
    [30, 55000, 14, 2, 3],
    [50, 90000, 19, 1, 5],
    [56, 32695, 14, 1, 2],
[46, 78190, 10, 4, 2],
[32, 35258, 10, 1, 1],
[60, 117538, 12, 2, 1],
[25, 69504, 11, 1, 1],
[38, 63159, 14, 4, 3],
[56, 43986, 21, 4, 5],
[36, 91858, 19, 4, 2],
[40, 42666, 15, 4, 2],
[28, 68660, 16, 4, 3],
[48, 119112, 19, 1, 2],
[27, 41130, 17, 2, 5],
[36, 117508, 15, 4, 5],
[49, 90566, 21, 1, 1],
[18, 96703, 17, 2, 5],
[22, 57192, 21, 2, 1],
[62, 31062, 14, 3, 4],
[21, 114076, 17, 1, 2],
[33, 119780, 19, 1, 2],
[41, 51545, 21, 4, 1]
])

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_

# Reduce dimensionality to 2D using PCA for visualization
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

# Visualize the clusters
plt.figure(figsize=(8, 6))

# Plot each cluster with a different color
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')

# Plot the centroids
centroids = pca.transform(kmeans.cluster_centers_)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=100, label='Centroids')

plt.title("K-means Clusters Visualized in 2D using PCA")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.show()
